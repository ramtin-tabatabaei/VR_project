# %%
#I used this code for finding the coornination of squares for persons
#Downloading a frame from both Animation and live-action

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import os
import cv2
import math
import random

# %%
# Number 1
XBminN1 = 100 #X Body min Near
XBmaxN1 = 450 #X Body max Near
YBminN1 = 300 #Y Body min Near
YBmaxN1 = 1000 #Y Body max Near

XFminN1 = 225 #X Face min Near
XFmaxN1 = 325
YFminN1 = 340
YFmaxN1 = 460


# XBminF1 = 290 #X Body min Far
# XBmaxF1 = 550 #X Body max Far
# YBminF1 = 380 #Y Body min Far
# YBmaxF1 = 900 #Y Body max Far

# XFminF1 = 375 #X Face min Far
# XFmaxF1 = 445
# YFminF1 = 390
# YFmaxF1 = 475


# Number 2
XBminN2 = 1450-700 #X Body min Near
XBmaxN2 = 1800-700 #X Body max Near
YBminN2 = 300 #Y Body min Near
YBmaxN2 = 1000 #Y Body max Near

XFminN2 = 1585-700 #X Face min Near
XFmaxN2 = 1685-700
YFminN2 = 340
YFmaxN2 = 460



# XBminF2 = 290+510 #X Body min Far
# XBmaxF2 = 550+510 #X Body max Far
# YBminF2 = 380 #Y Body min Far
# YBmaxF2 = 900 #Y Body max Far

# XFminF2 = 375+520 #X Face min Far
# XFmaxF2 = 445+540
# YFminF2 = 390
# YFmaxF2 = 475


# Number 3
# XBminN3 = 1450 #X Body min Near
# XBmaxN3 = 1800 #X Body max Near
# YBminN3 = 300 #Y Body min Near
# YBmaxN3 = 1000 #Y Body max Near

# XFminN3 = 1625-40 #X Face min Near
# XFmaxN3 = 1625+60
# YFminN3 = 340
# YFmaxN3 = 460


# XBminF3 = 290+1070 #X Body min Far
# XBmaxF3 = 550+1070 #X Body max Far
# YBminF3 = 380 #Y Body min Far
# YBmaxF3 = 900 #Y Body max Far

# XFminF3 = 375+1070 #X Face min Far
# XFmaxF3 = 445+1090
# YFminF3 = 390
# YFmaxF3 = 475

# %%
cap = cv2.VideoCapture(r'C:\Users\Ramtin\Desktop\Animation-Part 2.mkv')


width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH) + 0.5)
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT) + 0.5)
size = (width, height)

    
#Parameters    
i = 0
w = 0
counter = 0
max_rep = 0
showboundries = 1


while(cap.isOpened()):
    
    #For python
    ret, frame = cap.read()
    cv2.namedWindow("frame", cv2.WINDOW_NORMAL)        # Create window with freedom of dimensions
    cv2.resizeWindow("frame", 2000, 800)
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    
    #For time
    cv2.putText(frame,"t="+str(round(i/30,2))+"s", (100,100), cv2.FONT_HERSHEY_SIMPLEX, 1,(255,255,255),2)
    
    #participant stars
    # for j in range(12): #Participants
    #     cv2.putText(frame, "*", (int(frames[j,i,0]),int(frames[j,i,1])), cv2.FONT_HERSHEY_SIMPLEX, 0.5,(0,0,255),2)
    #cv2.putText(frame, "*", (265,int(415)), cv2.FONT_HERSHEY_SIMPLEX, 0.5,(0,0,255),2) #Near 1
    #cv2.putText(frame, "*", (930,int(415)), cv2.FONT_HERSHEY_SIMPLEX, 0.5,(0,0,255),2) #Near 2
    #cv2.putText(frame, "*", (1600,int(415)), cv2.FONT_HERSHEY_SIMPLEX, 0.5,(0,0,255),2) #Near 3
    cv2.putText(frame, "*", (420,int(435)), cv2.FONT_HERSHEY_SIMPLEX, 0.5,(0,0,255),2) #Far 1
    cv2.putText(frame, "*", (940,int(435)), cv2.FONT_HERSHEY_SIMPLEX, 0.5,(0,0,255),2) #Far 2
    cv2.putText(frame, "*", (1500,int(435)), cv2.FONT_HERSHEY_SIMPLEX, 0.5,(0,0,255),2) #Far 3
    if showboundries ==1:
        cv2.rectangle(frame,(XBminN1,YBminN1),(XBmaxN1,YBmaxN1),(0,255,0),3) # number 1 Near
        cv2.rectangle(frame,(XFminN1,YFminN1),(XFmaxN1,YFmaxN1),(0,255,0),3) # Face number 1 Near
        # cv2.rectangle(frame,(XBminF1,YBminF1),(XBmaxF1,YBmaxF1),(0,0,255),3) # number 1 Far
        # cv2.rectangle(frame,(XFminF1,YFminF1),(XFmaxF1,YFmaxF1),(0,0,255),3) # Face number 1 Far
        #cv2.putText(frame,"Number 1", (320-LBF,650-HBF-20), cv2.FONT_HERSHEY_SIMPLEX, 1,(255,255,255),2)
        
        cv2.rectangle(frame,(XBminN2,YBminN2),(XBmaxN2,YBmaxN2),(0,255,0),3) # number 2 Near
        cv2.rectangle(frame,(XFminN2,YFminN2),(XFmaxN2,YFmaxN2),(0,255,0),3) # Face number 2 Near
        cv2.rectangle(frame,(XBminF2,YBminF2),(XBmaxF2,YBmaxF2),(0,0,255),3) # number 2 Far
        cv2.rectangle(frame,(XFminF2,YFminF2),(XFmaxF2,YFmaxF2),(0,0,255),3) # Face number 2 Far
        #cv2.putText(frame,"Number 2", (720-LBN,690-HBN-20), cv2.FONT_HERSHEY_SIMPLEX, 1,(255,255,255),2)
        
        # cv2.rectangle(frame,(XBminN3,YBminN3),(XBmaxN3,YBmaxN3),(0,255,0),3) # number 3 Near
        # cv2.rectangle(frame,(XFminN3,YFminN3),(XFmaxN3,YFmaxN3),(0,255,0),3) # Face number 3 Near
        cv2.rectangle(frame,(XBminF3,YBminF3),(XBmaxF3,YBmaxF3),(0,0,255),3) # number 3 Far
        cv2.rectangle(frame,(XFminF3,YFminF3),(XFmaxF3,YFmaxF3),(0,0,255),3) # Face number 3 Far
        #cv2.putText(frame,"Number 3", (1180-LBN,705-HBN-20), cv2.FONT_HERSHEY_SIMPLEX, 1,(255,255,255),2)
        
   
    cv2.imshow('frame', frame)
    
    i += 1
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    cv2.waitKey(1)
    
    
cap.release()
cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %%
#Downloading a frame from real movie

# %%
import cv2

# Read the video file
cap = cv2.VideoCapture(r'F:\Courses\Paper\Mine\New\Process\Result\Real\Final_Real.mp4')

# Set the frame number to extract
frame_num = (98)*30

# Move the pointer to the desired frame
cap.set(cv2.CAP_PROP_POS_FRAMES, frame_num)

# Read the frame
ret, frame = cap.read()

cv2.putText(frame,"t="+str(round(frame_num/30,2))+"s", (100,100), cv2.FONT_HERSHEY_SIMPLEX, 1,(0,0,0),2)

cv2.rectangle(frame,(XBminN1,YBminN1),(XBmaxN1,YBmaxN1),(0,0,255),3) # number 1 Near
# cv2.rectangle(frame,(XFminN1,YFminN1),(XFmaxN1,YFmaxN1),(0,255,0),3) # Face number 1 Near
#cv2.rectangle(frame,(XWminN1-20,YWminN1),(XWmaxN1,YWmaxN1),(0,0,255),3) # Wave number 1 Near
# cv2.rectangle(frame,(XPminN1,YPminN1),(XPmaxN1,YPmaxN1),(0,255,0),3) # point number 1 Near
# cv2.rectangle(frame,(XBminF1,YBminF1),(XBmaxF1,YBmaxF1),(0,0,255),3) # number 1 Far
# cv2.rectangle(frame,(XFminF1,YFminF1),(XFmaxF1,YFmaxF1),(0,0,255),3) # Face number 1 Far
# cv2.rectangle(frame,(XWminF1,YWminF1),(XWmaxF1,YWmaxF1),(0,0,255),3) # Wave Number 1 Far
# cv2.rectangle(frame,(XPminF1,YPminF1),(XPmaxF1,YPmaxF1),(0,0,255),3) # point Number 1 Far
cv2.putText(frame,"Number 1", (XBminN1,YBminN1-20), cv2.FONT_HERSHEY_SIMPLEX, 1,(0,0,255),2)

# cv2.rectangle(frame,(XBminN2,YBminN2),(XBmaxN2,YBmaxN2),(0,255,0),3) # number 2 Near
# cv2.rectangle(frame,(XFminN2,YFminN2),(XFmaxN2,YFmaxN2),(0,255,0),3) # Face number 2 Near
# cv2.rectangle(frame,(XWminN2,YWminN2),(XWmaxN2,YWmaxN2),(0,255,0),3) # Wave number 2 Near
# cv2.rectangle(frame,(XPminN2,YPminN2),(XPmaxN2,YPmaxN2),(0,255,0),3) # point number 2 Near
cv2.rectangle(frame,(XBminF2,YBminF2),(XBmaxF2,YBmaxF2-50),(255,0,0),3) # number 2 Far
# cv2.rectangle(frame,(XFminF2,YFminF2),(XFmaxF2,YFmaxF2),(0,0,255),3) # Face number 2 Far
#cv2.rectangle(frame,(XWminF2,YWminF2),(XWmaxF2,YWmaxF2),(255,0,0),3) # Wave Number 2 Far
#cv2.rectangle(frame,(XPminF2+10,YPminF2-10),(XPmaxF2+15,YPmaxF2-5),(255,0,0),3) # point Number 2 Far
cv2.putText(frame,"Number 2", (XBminF2,YBminF2-20), cv2.FONT_HERSHEY_SIMPLEX, 1,(255,0,0),2)

cv2.rectangle(frame,(XBminN3,YBminN3),(XBmaxN3-50,YBmaxN3),(0,0,255),3) # number 3 Near
# cv2.rectangle(frame,(XFminN3,YFminN3),(XFmaxN3,YFmaxN3),(0,255,0),3) # Face number 3 Near
# cv2.rectangle(frame,(XWminN3,YWminN3),(XWmaxN3,YWmaxN3),(0,255,0),3) # Wave number 3 Near
# cv2.rectangle(frame,(XPminN3,YPminN3),(XPmaxN3,YPmaxN3),(0,255,0),3) # point number 3 Near
# cv2.rectangle(frame,(XBminF3,YBminF3),(XBmaxF3,YBmaxF3),(0,0,255),3) # number 3 Far
# cv2.rectangle(frame,(XFminF3,YFminF3),(XFmaxF3,YFmaxF3),(0,0,255),3) # Face number 3 Far
# cv2.rectangle(frame,(XWminF3,YWminF3),(XWmaxF3,YWmaxF3),(0,0,255),3) # Wave Number 3 Far
# cv2.rectangle(frame,(XPminF3,YPminF3),(XPmaxF3,YPmaxF3),(0,0,255),3) # point Number 3 Far
cv2.putText(frame,"Number 3", (XBminN3,YBminN3-20), cv2.FONT_HERSHEY_SIMPLEX, 1,(0,0,255),2)

# cv2.rectangle(frame,(XBminN4,YBminN4),(XBmaxN4,YBmaxN4),(0,255,0),3) # number 4 Near
# cv2.rectangle(frame,(XFminN4,YFminN4),(XFmaxN4,YFmaxN4),(0,255,0),3) # Face number 4 Near
# cv2.rectangle(frame,(XWminN4,YWminN4),(XWmaxN4,YWmaxN4),(0,255,0),3) # Wave number 4 Near
# cv2.rectangle(frame,(XPminN4,YPminN4),(XPmaxN4,YPmaxN4),(0,255,0),3) # point number 4 Near
cv2.rectangle(frame,(XBminF4-20,YBminF4),(XBmaxF4-20,YBmaxF4),(0,0,255),3) # number 4 Far
# cv2.rectangle(frame,(XFminF4,YFminF4),(XFmaxF4,YFmaxF4),(0,0,255),3) # Face number 4 Far
# cv2.rectangle(frame,(XWminF4,YWminF4),(XWmaxF4,YWmaxF4),(0,0,255),3) # Wave Number 4 Far
# cv2.rectangle(frame,(XPminF4,YPminF4),(XPmaxF4,YPmaxF4),(0,0,255),3) # point Number 4 Far
cv2.putText(frame,"Number 4", (XBminF4,YBminF4-20), cv2.FONT_HERSHEY_SIMPLEX, 1,(0,0,255),2)

cv2.rectangle(frame,(XBoxmin,YBoxmin),(XBoxmax,YBoxmax),(0,0,0),3) # Box
cv2.putText(frame,"Box", (XBoxmin+50,YBoxmin-10), cv2.FONT_HERSHEY_SIMPLEX, 1,(0,0,0),2)


# Check if the frame was successfully read
if ret:
    # Save the frame as an image file
    cv2.imwrite('frame.png', frame)

# Release the video capture object and close all windows
cap.release()
cv2.destroyAllWindows()

# %%
#Downloading a frame from Animation movie

# %%
LBN = 145 #Length Body Near
HBN = 355 #Height Body Near

LFN = 50 #Length Face Near
HFN = 90 #Height Face Near

LWN = 45 #Length Wave Near
HWN = 50 #Height Wave Near

LPN = 35 #Length Pointing Near


LBF = 105 #Length Body Far
HBF = 250 #Height Body Far

LFF = 30 #Length Face Far
HFF = 70 #Height Face Far

LWF = 30 #Length Wave Far
HWF = 35 #Height Wave Far

LPF = 25 #Length Pointing Far




import cv2

# Read the video file
cap = cv2.VideoCapture(r"F:\Courses\Paper\Mine\New\Process\Result\Animation\Animation_(final).mp4")


# Set the frame number to extract
frame_num = (38)*30

# Move the pointer to the desired frame
cap.set(cv2.CAP_PROP_POS_FRAMES, frame_num)

# Read the frame
ret, frame = cap.read()

cv2.putText(frame,"t="+str(round(frame_num/30,2))+"s", (100,100), cv2.FONT_HERSHEY_SIMPLEX, 1,(0,0,0),2)

#cv2.rectangle(frame,(260-LBN,690-HBN),(260+LBN,690+HBN),(0,0,255),3) # number 1 Near
#cv2.rectangle(frame,(260-LFN,435-HFN),(260+LFN,435+HFN),(0,255,0),3) # Face number 1 Near
#cv2.rectangle(frame,(357-LWN,390-HWN),(357+LWN,390+HWN),(0,255,0),3) # Wave number 1 Near
#cv2.rectangle(frame,(323-LPN,630-LPN),(323+LPN,630+LPN),(0,0,255),3) # point number 1 Near
cv2.rectangle(frame,(320-LBF,650-HBF),(320+LBF,650+HBF),(255,0,0),3) # number 1 Far
# cv2.rectangle(frame,(330-LFF,470-HFF),(330+LFF,470+HFF),(0,0,255),3) # Face number 1 Far
#cv2.rectangle(frame,(390-LWF,445-HWF),(390+LWF,445+HWF),(0,0,255),3) # Wave Number 1 Far
# cv2.rectangle(frame,(340-LPF,605-LPF),(340+LPF,605+LPF),(0,0,255),3) # point Number 1 Far
cv2.putText(frame,"Number 1", (320-LBF,650-HBF-10), cv2.FONT_HERSHEY_SIMPLEX, 1,(255,0,0),2)

#cv2.rectangle(frame,(720-LBN,690-HBN),(720+LBN,690+HBN),(0,255,0),3) # number 2 Near
#cv2.rectangle(frame,(720-LFN,435-HFN),(720+LFN,435+HFN),(0,255,0),3) # Face number 2 Near
# cv2.rectangle(frame,(817-LWN,390-HWN),(817+LWN,390+HWN),(0,255,0),3) # Wave number 2 Near
# cv2.rectangle(frame,(750-LPN,625-LPN),(750+LPN,625+LPN),(0,255,0),3) # Point number 2 Near
#cv2.rectangle(frame,(715-LBF,650-HBF),(715+LBF,650+HBF),(255,0,0),3) # number 2 Far
# cv2.rectangle(frame,(720-LFF,470-HFF),(720+LFF,470+HFF),(0,0,255),3) # Face Number 2 Far
#cv2.rectangle(frame,(790-LWF,445-HWF-5),(790+LWF,445+HWF-5),(255,0,0),3) # Wave Number 2 Far
#cv2.rectangle(frame,(715-LPF,595-LPF),(715+LPF,595+LPF),(0,0,255),3) # Point Number 2 Far
#cv2.putText(frame,"Number 2", (715-LBF,650-HBF-10), cv2.FONT_HERSHEY_SIMPLEX, 1,(255,0,0),2)

cv2.rectangle(frame,(1180-LBN+50,690-HBN),(1180+LBN+20,690+HBN),(0,0,255),3) # number 3 Near
# cv2.rectangle(frame,(1185-LFN,435-HFN),(1185+LFN,435+HFN),(0,255,0),3) # Face number 3 Near
#cv2.rectangle(frame,(1280-LWN+10,390-HWN),(1280+LWN+10,390+HWN),(0,0,255),3) # Waving number 3 Near
# cv2.rectangle(frame,(1125-LPN,640-LPN),(1125+LPN,640+LPN),(0,255,0),3) # Pointing number 3 Near
# cv2.rectangle(frame,(1190-LBF,650-HBF),(1190+LBF,650+HBF),(0,0,255),3) # number 3 Far
# cv2.rectangle(frame,(1190-LFF,470-HFF),(1190+LFF,470+HFF),(0,0,255),3) # Face number 3 Far
#cv2.rectangle(frame,(1265-LWF,445-HWF),(1265+LWF,445+HWF),(0,0,255),3) # Wave number 3 Far
# cv2.rectangle(frame,(1150-LPF,610-LPF),(1150+LPF,610+LPF),(0,0,255),3) # Point number 3 Far
cv2.putText(frame,"Number 3", (1180-LBN+50,690-HBN-10), cv2.FONT_HERSHEY_SIMPLEX, 1,(0,0,255),2)

# cv2.rectangle(frame,(1655-LBN-5,690-HBN),(1655+LBN+5,690+HBN),(0,255,0),3) # number 4 Near
# cv2.rectangle(frame,(1655-LFN,435-HFN),(1655+LFN,435+HFN),(0,255,0),3) # Face number 4 Near
#  cv2.rectangle(frame,(1755-LWN,390-HWN),(1755+LWN,390+HWN),(0,255,0),3) # Wave number 4 Near
#  cv2.rectangle(frame,(1540-LPN,635-LPN),(1540+LPN,635+LPN),(0,255,0),3) # Point number 4 Near
#cv2.rectangle(frame,(1580-LBF,650-HBF),(1580+LBF,650+HBF),(255,0,0),3) # number 4 Far
# cv2.rectangle(frame,(1590-LFF,470-HFF),(1590+LFF,470+HFF),(0,0,255),3) # Face number 4 Far
# cv2.rectangle(frame,(1650-LWF,445-HWF),(1650+LWF,445+HWF),(0,0,255),3) # Wave number 4 Far
#cv2.rectangle(frame,(1520-LPF+10,615-LPF),(1520+LPF+10,615+LPF),(255,0,0),3) # Point number 4 Far
#cv2.putText(frame,"Number 4", (1580-LBF,650-HBF-10), cv2.FONT_HERSHEY_SIMPLEX, 1,(255,0,0),2)

cv2.rectangle(frame,(840,1070),(1070,830),(0,0,0),3) # Box
cv2.putText(frame,"Box", (840+50,830-10), cv2.FONT_HERSHEY_SIMPLEX, 1,(0,0,0),2)


# Check if the frame was successfully read
if ret:
    # Save the frame as an image file
    cv2.imwrite('frame2.png', frame)

# Release the video capture object and close all windows
cap.release()
cv2.destroyAllWindows()
