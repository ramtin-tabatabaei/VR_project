# %%
#It is a good code for recorning the video For Real

# %%
# %matplotlib inline
import numpy as np
import cv2
import random
import datetime as dt
import tensorflow as tf
from collections import deque
import matplotlib.pyplot as plt
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
import math

# %%
#Parameters
record = 1 # on=1 off=0
namerec = "sequence30-NTD10-K1-LSTM"
radius = 20  # Radius of the circle

# %%
import os

directory = r"F:\Courses\Paper\Mine\Paper3\Data"

# get a list of all .txt files in the directory
txt_files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith('.txt')]

# print the number of .txt files found
print("Number of txt files:", len(txt_files))

# read the contents of each .txt file and store them in an array
Data = np.zeros((len(txt_files),50000,4))
for file_path in txt_files:
    for i in range(len(txt_files)):
        data = np.loadtxt(txt_files[i], dtype=object)
        data = [line.split(',') for line in data]

        # Convert the resulting list of lists to a NumPy array with the appropriate data types
        data = np.array(data, dtype=np.float32)
        #data = data.astype(np.int32)
        A = np.zeros((50000-data.shape[0], data.shape[1]))
        Data[i] = np.concatenate((data, A))
# Out:
# Number of txt files: 11

# %%
import pandas as pd

# Load the Excel file into a DataFrame
df = pd.read_excel(r'F:\Courses\Paper\Mine\Paper3\Animation\For recording\Properties-Part1.xlsx', sheet_name='Sheet1')

# Select the values from row 3 and onwards
Properties_Ani = df.values[1:]

# %%
# Load the Excel file into a DataFrame
df = pd.read_excel(r'F:\Courses\Paper\Mine\Paper3\Properties.xlsx', sheet_name='Sheet1')

# Select the values from row 3 and onwards
Properties_Uni = df.values[1:]

# %%
import numpy as np

# Assume the data array is already loaded into a variable named 'data'

# Find the indices where the values are "N" or "F"
idx_n = np.where(Properties_Ani == np.array(["N"], dtype=str))
idx_f = np.where(Properties_Ani == np.array(["F"], dtype=str))

# Replace "N" with "1"
Properties_Ani[idx_n] = 1

# Replace "F" with "2"
Properties_Ani[idx_f] = 2

# Find the indices where the values are "N" or "F"
idx_n = np.where(Properties_Uni == np.array(["N"], dtype=str))
idx_f = np.where(Properties_Uni == np.array(["F"], dtype=str))

# Replace "N" with "1"
Properties_Uni[idx_n] = 1

# Replace "F" with "2"
Properties_Uni[idx_f] = 2

# %%
Properties_Ani = np.array(Properties_Ani)
Properties_Ani = Properties_Ani.astype(float)
Properties_Uni = np.array(Properties_Uni)
Properties_Uni = Properties_Uni.astype(float)

# %%
resulotion = 1/30
Dim = round((Properties_Ani[-1,0]-Properties_Ani[0,0])/resulotion)
Properties_Ani_res = np.zeros((Dim, Properties_Ani.shape[1]))
t0 = 0
tf = 303
t = t0
Properties_Ani_inter = 0

for i in range(Dim):
    Properties_Ani_res[i] = Properties_Ani[Properties_Ani_inter]
    Properties_Ani_res[i,0] = t
    if t >= Properties_Ani[Properties_Ani_inter+1,0]:
        Properties_Ani_inter += 1
    
    t += resulotion

# %%
Dim = round((Properties_Uni[-1,0]-Properties_Uni[0,0])/resulotion)
Properties_Uni_res = np.zeros((Dim, Properties_Uni.shape[1]))
Data_res = np.zeros((len(txt_files), Dim, Data.shape[2]))
t0 = 5
tf = 620.8
t = t0
Data_inter = np.zeros(len(txt_files),dtype="int")
Properties_Uni_inter = 0
#for j in range(len(txt_files)):
for j in range(1):
    for i in range(Data[j].shape[0]):
        if Data[j,i,0] >= t0:
            Data_inter[j] = i - 1
            break
for i in range(Dim):
    Properties_Uni_res[i] = Properties_Uni[Properties_Uni_inter]
    Properties_Uni_res[i,0] = t
    if t >= Properties_Uni[Properties_Uni_inter+1,0]:
        Properties_Uni_inter += 1
    for j in range(len(txt_files)):
        if Data[j,Data_inter[j]+2,0]==0:
            continue
        Data_res[j,i] = Data[j, Data_inter[j]]
        Data_res[j,i,0] = t
        while True:
            if t >= Data[j, Data_inter[j] + 1,0]:
                Data_inter[j] += 1
            else:
                break
    
    t += resulotion

# %%
# Number 1
XBminN1 = 122 #X Body min Near
XBmaxN1 = 167 #X Body max Near

XBminF1 = 155 #X Body min Far
XBmaxF1 = 175 #X Body max Far


# Number 2
XBminN2 = 170 #X Body min Near
XBmaxN2 = 195 #X Body max Near

XBminF2 = 180 #X Body min Far
XBmaxF2 = 200 #X Body max Far


# Number 3
XBminN3 = 200 #X Body min Near
XBmaxN3 = 235 #X Body max Near

XBminF3 = 203 #X Body min Far
XBmaxF3 = 218 #X Body max Far

# %%
Model_data = np.zeros((Data_res.shape[0]*Data_res.shape[1],Properties_Uni_res.shape[1]))
Model_label = np.zeros((Data_res.shape[0]*Data_res.shape[1]), dtype="O")
inter = 0
for z in range(Data_res.shape[0]):
    for j in range(Data_res.shape[1]):
        if Data_res[z,j,0] == 0:
            continue
        Model_data[inter] = Properties_Uni_res[j]
        Model_label[inter] = "No Data"

        P = 0 # number of person 1
        if Properties_Uni_res[j,6*P+1] == 1: #if the person is present
            if Properties_Uni_res[j,6*P+2] == 1: #if the person is Near or Far
                if Properties_Uni_res[j,6*P+3] != 7: #if the person is stationary or Entering or Leaving
                    if XBminN1<Data_res[z,j,2]<XBmaxN1: #Body
                        Model_label[inter] = "Number 1"
                            
                elif Properties_Uni_res[j,6*P+3] == 7:  #if the person is stationary or moving
                    if 100<Data_res[z,j,2]<XBmaxN1: #Body
                        Model_label[inter] = "Number 1"

                        
            elif Properties_Uni_res[j,6*P+2] == 2: #if the person is Near or Far
                if Properties_Uni_res[j,6*P+3] != 7: #if the person is stationary or Entering or Leaving
                    if XBminF1<Data_res[z,j,2]<XBmaxF1: #Body
                        Model_label[inter] = "Number 1"

                elif Properties_Uni_res[j,6*P+3] == 7:  #if the person is stationary or moving
                    if 100<Data_res[z,j,2]<XBmaxN1: #Body
                        Model_label[inter] = "Number 1"


        P = 1 # number of person 2
        if Properties_Uni_res[j,6*P+1] == 1: #if the person is present
            if Properties_Uni_res[j,6*P+2] == 1: #if the person is Near or Far
                if Properties_Uni_res[j,6*P+3] != 7: #if the person is stationary or Entering or Leaving
                    if XBminN2<Data_res[z,j,2]<XBmaxN2: #Body
                        Model_label[inter] = "Number 2"
                            
                elif Properties_Uni_res[j,6*P+3] == 7:  #if the person is stationary or moving
                    if Properties_Uni_res[j,6*P+6] <=0:  #if the person is leaving or entering from left side
                        if 100<Data_res[z,j,2]<180: #Body
                            Model_label[inter] = "Number 2"
                    elif Properties_Uni_res[j,6*P+6] >=0:  #if the person is leaving or entering from left side
                        if 180<Data_res[z,j,2]<250: #Body
                            Model_label[inter] = "Number 2"
                            

            elif Properties_Uni_res[j,6*P+2] == 2: #if the person is Near or Far
                if Properties_Uni_res[j,6*P+3] != 7: #if the person is stationary or Entering or Leaving
                    if XBminF2<Data_res[z,j,2]<XBmaxF2: #Body
                        Model_label[inter] = "Number 2"

                            
                elif Properties_Uni_res[j,6*P+3] == 7:  #if the person is stationary or moving
                    if Properties_Uni_res[j,6*P+6] <=0:  #if the person is leaving or entering from left side
                        if 100<Data_res[z,j,2]<180: #Body
                            Model_label[inter] = "Number 2"
                    elif Properties_Uni_res[j,6*P+6] >=0:  #if the person is leaving or entering from left side
                        if 180<Data_res[z,j,2]<250: #Body
                            Model_label[inter] = "Number 2"
                            

        P = 2 # number of person 3
        if Properties_Uni_res[j,6*P+1] == 1: #if the person is present
            if Properties_Uni_res[j,6*P+2] == 1: #if the person is Near or Far
                if Properties_Uni_res[j,6*P+3] != 7: #if the person is stationary or Entering or Leaving
                    if XBminN3<Data_res[z,j,2]<XBmaxN3: #Body
                        Model_label[inter] = "Number 3"
                            
                elif Properties_Uni_res[j,6*P+3] == 7:  #if the person is stationary or moving
                    if XBminN3<Data_res[z,j,2]<250: #Body
                        Model_label[inter] = "Number 3"

            elif Properties_Uni_res[j,6*P+2] == 2: #if the person is Near or Far
                if Properties_Uni_res[j,6*P+3] != 7: #if the person is stationary or Entering or Leaving
                    if XBminF3<Data_res[z,j,2]<XBmaxF3: #Body
                        Model_label[inter] = "Number 3"
                        
                elif Properties_Uni_res[j,6*P+3] == 7:  #if the person is stationary or moving
                        if XBminF3<Data_res[z,j,2]<250: #Body
                            Model_label[inter] = "Number 3"
        inter +=1

# %%
Model_data = np.array(Model_data[0:inter])
Model_label = np.array(Model_label[0:inter])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler = scaler.fit(Model_data)
Model_data_normal = scaler.transform(Model_data)  #scale the data

Model_data_normal = np.delete(Model_data_normal, 0, axis=1)

# %%
def Labell(String):
    if String == "Number 1":
        return 0
    elif String == "Number 2":
        return 1
    elif String == "Number 3":
        return 2

# %%
Persons_inter = np.zeros(len(txt_files))
inter = 0
for i in range(Model_data.shape[0]):
    if Model_data[i, 0] == 5:
        Persons_inter[inter] = i
        inter += 1

# %%
Persons_inter
# Out:
# array([     0.,  12133.,  30607.,  49081.,  67555.,  86029., 104503.,
#        122977., 141451., 159925., 178399.])

# %%
Model_label[86029+31]
# Out:
# 'No Data'

# %%
Data_res[5,31]
# Out:
# array([  6.03333333,   5.04101086, 169.91389465, 356.26309204])

# %%
Data_res.shape
# Out:
# (11, 18474, 4)

# %%
Properties_res = np.array(Properties_Ani_res[:,1:19])

# %%
sequence = 30
Model_data_normal_sequence = np.zeros((Properties_res.shape[0],sequence,Properties_res.shape[1]),dtype='float')
inter = 0
for i in range(Model_data_normal_sequence.shape[0]-sequence):
    for j in range(sequence):
        Model_data_normal_sequence[inter,j] = Properties_res[i+j]
    inter += 1
        
Model_data_normal_sequence = np.array(Model_data_normal_sequence[0:inter])

# %%
import tensorflow as tf
class PositionalEmbedding(tf.keras.layers.Layer):
    def __init__(self, sequence_length, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.position_embeddings = tf.keras.layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim
        )
        self.sequence_length = sequence_length
        self.output_dim = output_dim

    def call(self, inputs):
        # The inputs are of shape: `(batch_size, frames, num_features)`
        length = tf.shape(inputs)[1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_positions = self.position_embeddings(positions)
        return inputs + embedded_positions

    def compute_mask(self, inputs, mask=None):
        mask = tf.reduce_any(tf.cast(inputs, "bool"), axis=-1)
        return mask

# %%
class TransformerEncoder(tf.keras.layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = tf.keras.layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.dense_proj = tf.keras.Sequential(
            [tf.keras.layers.Dense(dense_dim, activation='swish'),tf.keras.layers.Dense(embed_dim, activation='swish')]
        )
        self.layernorm_1 = tf.keras.layers.LayerNormalization()
        self.layernorm_2 = tf.keras.layers.LayerNormalization()

    def call(self, inputs, mask=None):
        if mask is not None:
            mask = mask[:, tf.newaxis, :]

        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

# %%
import tensorflow as tf
from tensorflow import keras
import h5py

tf.keras.utils.get_custom_objects()['PositionalEmbedding'] = PositionalEmbedding
tf.keras.utils.get_custom_objects()['TransformerEncoder'] = TransformerEncoder
# Load the model
loaded_model = tf.keras.models.load_model(r'F:\Courses\Paper\Mine\Paper3\Results\Transformers-K2-TTP0.8-sequence30.h5', compile=False)

# %%
Model_data_normal_sequence.shape
# Out:
# (9060, 30, 18)

# %%
y_pred = loaded_model.predict(Model_data_normal_sequence)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 y_pred = loaded_model.predict(Model_data_normal_sequence)
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_filezzbut0jd.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__predict_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# File ~\AppData\Local\Temp\__autograph_generated_filecqig13km.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__call(self, inputs)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.ld(inputs) + ag__.ld(embedded_positions)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "C:\Users\Ramtin\anaconda3\lib\site-packages\keras\engine\training.py", line 2169, in predict_function  *
#         return step_function(self, iterator)
#     File "C:\Users\Ramtin\anaconda3\lib\site-packages\keras\engine\training.py", line 2155, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\Ramtin\anaconda3\lib\site-packages\keras\engine\training.py", line 2143, in run_step  **
#         outputs = model.predict_step(data)
#     File "C:\Users\Ramtin\anaconda3\lib\site-packages\keras\engine\training.py", line 2111, in predict_step
#         return self(x, training=False)
#     File "C:\Users\Ramtin\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\Ramtin\AppData\Local\Temp\__autograph_generated_filecqig13km.py", line 15, in tf__call
#         retval_ = ag__.ld(inputs) + ag__.ld(embedded_positions)
#
#     ValueError: Exception encountered when calling layer 'frame_position_embedding' (type PositionalEmbedding).
#
#     in user code:
#
#         File "C:\Users\Ramtin\AppData\Local\Temp\ipykernel_5160\3942188455.py", line 16, in call  *
#             return inputs + embedded_positions
#
#         ValueError: Dimensions must be equal, but are 18 and 15 for '{{node model/frame_position_embedding/add}} = AddV2[T=DT_FLOAT](IteratorGetNext, model/frame_position_embedding/embedding_2/embedding_lookup/Identity_1)' with input shapes: [?,30,18], [30,15].
#
#
#     Call arguments received by layer 'frame_position_embedding' (type PositionalEmbedding):
#       • inputs=tf.Tensor(shape=(None, 30, 18), dtype=float32)

# %%
Model_data_normal_sequence[0,-1]
# Out:
# array([  1.,   1.,   7.,   0.,   0., -75.,   1.,   2.,   7.,   0.,   0.,
#         60.,   0.,   0.,   0.,   0.,   0.,   0.])

# %%
y_pred[0]
# Out:
# array([0.49936345, 0.45772004, 0.04291647], dtype=float32)

# %%
#y_pred = model.predict(X_train)
y_pred = loaded_model.predict(Model_data_normal_sequence)
Label = np.zeros(y_pred.shape[0],dtype='int') 
for i in range(Label.shape[0]):
    a=y_pred[i]
    a=a.argmax()
    if Model_data_normal_sequence[250*30,-1,6*a]==0:
        y_pred[i,a]=0
        a=y_pred[i]
        a=a.argmax()
    Label[i] = a
# Out:
# 284/284 [==============================] - 3s 11ms/step

# %%
mylist = ['Number 1',
          'Number 2',
          'Number 3']

# %%
Properties_res[100]
# Out:
# array([  1.,   1.,   7.,   0.,   0., -45.,   1.,   2.,   7.,   0.,   0.,
#         30.,   0.,   0.,   0.,   0.,   0.,   0.])

# %%
def Participants_look(Object,i):
    XX = 0
    YY = 0

    if Object =='Number 1':
        if Properties_res[i,1]==1:
            XX = int(5.5*Properties_res[i,5]+512.5)
            YY = int(415)

        else:
            XX = int(10.66*Properties_res[i,5]+740)
            YY = int(435)
           
            
    elif Object =='Number 2':
        if Properties_res[i,7]==1:
            XX = int(11.06*Properties_res[i,11]+930)
            YY = int(415)
        else:                       
            XX = int(14.66*Properties_res[i,11]+940)
            YY = int(435)
                
                    
    elif Object =='Number 3':
        if Properties_res[i,12]==1:
            XX = int(7.33*Properties_res[i,17]+1270)
            YY = int(415)
                
        else:
            XX = int(10.66*Properties_res[i,17]+1180)
            YY = int(435)

    return XX,YY

# %%
from scipy.stats import multivariate_normal

def Star(Object,i):
    max_rep = 0
    multipy = 100  #50
    power = 2 #2
    XX = 0
    YY = 0

    if Object =='Number 1':
        if Properties_res[i,1]==1:
            if Properties_res[i,2]!=7 and Properties_res[i,2]!=2:
                max_rep = 0
                #max_rep = 6
                #XX = int(5.5*Properties_res[i,5]+512.5)
                #YY = int(415)
                Mean1N = np.array([265, 415])
                cov1N = np.array([[440, 73],[73, 730]])
                while max_rep<5:
                    x, y = np.random.multivariate_normal(Mean1N, cov1N, 1).T
                    var = multivariate_normal(mean=Mean1N, cov=cov1N)
                    max_rep = round((var.pdf(np.array([x[0],y[0]]))/var.pdf(Mean1N))**power*multipy)
                    XX = round(x[0])
                    YY = round(y[0])
            else:
                XX = int(5.5*Properties_res[i,5]+512.5)
                YY = int(415)

        else:
            if Properties_res[i,2]!=7 and Properties_res[i,2]!=2:
                max_rep = 0
                Mean1F = np.array([420, 435])
                cov1F = np.array([[232, 28],[28, 534]])
                while max_rep<5:
                    x, y = np.random.multivariate_normal(Mean1F, cov1F, 1).T
                    var = multivariate_normal(mean=Mean1F, cov=cov1F)
                    max_rep = round((var.pdf(np.array([x[0],y[0]]))/var.pdf(Mean1F))**power*multipy)
                    XX = round(x[0])
                    YY = round(y[0])
            else:
                XX = int(10.66*Properties_res[i,5]+740)
                YY = int(435)
           
            
    elif Object =='Number 2':
        if Properties_res[i,7]==1:
            if Properties_res[i,8]!=7 and Properties_res[i,8]!=2:
                max_rep = 0
                Mean2N = np.array([930, 415])
                cov2N = np.array([[442, 34],[34, 447]])
                while max_rep<5:
                    x, y = np.random.multivariate_normal(Mean2N, cov2N, 1).T
                    var = multivariate_normal(mean=Mean2N, cov=cov2N)
                    max_rep = round((var.pdf(np.array([x[0],y[0]]))/var.pdf(Mean2N))**power*multipy)
                    XX = round(x[0])
                    YY = round(y[0])
            else:
                XX = int(11.06*Properties_res[i,11]+930)
                YY = int(415)
        else:                       
            if Properties_res[i,8]!=7 and Properties_res[i,8]!=2:
                max_rep = 0
                Mean2F = np.array([940, 435])
                cov2F = np.array([[216, 48],[48, 464]])
                while max_rep<5:
                    x, y = np.random.multivariate_normal(Mean2F, cov2F, 1).T
                    var = multivariate_normal(mean=Mean2F, cov=cov2F)
                    max_rep = round((var.pdf(np.array([x[0],y[0]]))/var.pdf(Mean2F))**power*multipy)
                    XX = round(x[0])
                    YY = round(y[0])
            else:
                XX = int(14.66*Properties_res[i,11]+940)
                YY = int(435)
                
                    
    elif Object =='Number 3':
        if Properties_res[i,12]==1:
            if Properties_res[i,13]!=7 and Properties_res[i,13]!=2:
                max_rep = 0
                Mean3N = np.array([1600, 415])
                cov3N = np.array([[440, 73],[73, 730]])
                while max_rep<5:
                    x, y = np.random.multivariate_normal(Mean3N, cov3N, 1).T
                    var = multivariate_normal(mean=Mean3N, cov=cov3N)
                    max_rep = round((var.pdf(np.array([x[0],y[0]]))/var.pdf(Mean3N))**power*multipy)
                    XX = round(x[0])
                    YY = round(y[0])
                
            else:
                XX = int(7.33*Properties_res[i,17]+1270)
                YY = int(415)
                
        else:
            if Properties_res[i,12]!=7 and Properties_res[i,12]!=2:
                max_rep = 0
                Mean3F = np.array([1500, 435])
                cov3F = np.array([[232, 28],[28, 534]])
                while max_rep<5:
                    x, y = np.random.multivariate_normal(Mean3F, cov3F, 1).T
                    var = multivariate_normal(mean=Mean3F, cov=cov3F)
                    max_rep = round((var.pdf(np.array([x[0],y[0]]))/var.pdf(Mean3F))**power*multipy)
                    XX = round(x[0])
                    YY = round(y[0])
            else:
                XX = int(10.66*Properties_res[i,17]+1180)
                YY = int(435)

    return XX,YY, max_rep

# %%
cap = cv2.VideoCapture(r'F:\Courses\Paper\Mine\Paper3\Animation\For recording\Animation-Part 1.mkv')

record = 1
delta = 1

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH) + 0.5)
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT) + 0.5)
size = (width, height)
if record == 1:
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter(r"F:\Courses\Paper\Mine\Paper3/"+namerec+".avi", fourcc, 30.0, size)

    
#Parameters    
i = 0
w = 0
counter = 0
max_rep = 0
str_count = "Hi"
XX_old = 1920/2
YY_old = 900

while(cap.isOpened()):
    
    #For python
    ret, frame = cap.read()
    if ret == False or i==30*5*60:
        break
        
    cv2.namedWindow("frame", cv2.WINDOW_NORMAL)        # Create window with freedom of dimensions
    cv2.resizeWindow("frame", 2000, 800)
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    #For time
    cv2.putText(frame,"t="+str(round(i/30,2))+"s", (100,100), cv2.FONT_HERSHEY_SIMPLEX, 1,(255,255,255),2)
    
    #Participants
    #for j in Persons_inter:
    #    Look_X, Look_Y = Participants_look(Model_label[int(j)+i],i)
    #    cv2.putText(frame, "*", (Look_X, Look_Y), cv2.FONT_HERSHEY_SIMPLEX, 1,(0,0,255),2) #Detecter Model
        
    for j in range(Persons_inter.shape[0]):
        angle = j * (2 * math.pi / num_stars)
        x =  radius * math.cos(angle)
        y =  radius * math.sin(angle)
        Look_X, Look_Y = Participants_look(Model_label[int(Persons_inter[j])+i],i)
        if Look_X>0:
            cv2.putText(frame, "*", (Look_X+int(x), Look_Y+int(y)), cv2.FONT_HERSHEY_SIMPLEX, 1,(0,0,255),2) #Detecter Model
            


    #For detect
    if i >= sequence:
        #Update after delta
        if i%delta == 0: 
            A = Label[w]
            w = w + 1
            print(y_pred[i])

        if str_count != mylist[A] or counter >= max_rep:
            str_count = mylist[A]
            XX, YY, max_rep = Star(mylist[A],i) 
            counter = 0
        else:
            counter = counter + 1

    else:
        XX = int(XX_old)
        YY = int(YY_old)

    XX_draw = int(XX_old + (XX - XX_old)/10)
    YY_draw = int(YY_old + (YY - YY_old)/10)

    XX_old = XX_draw
    YY_old = YY_draw


    cv2.putText(frame, "*", (XX_draw, YY_draw), cv2.FONT_HERSHEY_SIMPLEX, 1,(255,255,255),2) #Detecter Model


    if record==1:
        out.write(frame)

    cv2.imshow('frame', frame)
    
    i += 1
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    cv2.waitKey(1)
    
    
cap.release()
cv2.destroyAllWindows()
# Out:
# [0.71002495 0.26321608 0.02675902]
# [0.71040654 0.2629248  0.02666869]
# [0.7107508  0.26265943 0.02658976]
# [0.71106285 0.26241684 0.02652039]
# [0.7113467  0.26219428 0.026459  ]
# [0.711606   0.26198974 0.02640431]
# [0.7118435  0.26180127 0.02635526]
# [0.7120618  0.26162726 0.02631095]
# [0.71226305 0.26146638 0.02627067]
# [0.71244895 0.26131725 0.02623379]
# [0.71262157 0.26117858 0.02619976]
# [0.7127828  0.2610491  0.02616816]
# [0.71293426 0.2609273  0.02613853]
# [0.71307814 0.26081133 0.02611047]
# [0.71321714 0.2606994  0.02608353]
# [0.71335393 0.26058874 0.02605727]
# [0.71685004 0.25783077 0.02531915]
# [0.7205594  0.25514778 0.02429281]
# [0.7224388  0.25396082 0.02360032]
# [0.7241708  0.25286698 0.02296221]
# [0.7253642  0.2521947  0.02244109]
# [0.7261478  0.25184688 0.02200535]
# [0.7266521  0.25170833 0.02163967]
# [0.72694224 0.25172403 0.02133368]
# [0.7270737  0.25184852 0.0210778 ]
# [0.7270863  0.25204992 0.02086374]
# [0.727009   0.25230637 0.02068463]
# [0.72686285 0.25260246 0.02053477]
# [0.7266633  0.25292727 0.02040943]
# [0.72642237 0.25327295 0.0203047 ]
# [0.7261488  0.25363392 0.02021732]
# [0.7258492  0.25400624 0.02014455]
# [0.7255287  0.25438717 0.02008417]
# [0.72519124 0.2547746  0.02003426]
# [0.72483957 0.25516722 0.01999327]
# [0.72447604 0.25556415 0.01995982]
# [0.724102   0.2559651  0.01993285]
# [0.7237184  0.25637046 0.0199111 ]
# [0.7233223  0.25678587 0.01989178]
# [0.72289056 0.25725016 0.01985923]
# [0.72226965 0.2580199  0.01971048]
# [0.72086424 0.26019716 0.01893862]
# [0.7197865  0.26271734 0.01749616]
# [0.71863824 0.2645518  0.01680999]
# [0.71687245 0.2665112  0.01661631]
# [0.71509266 0.26831418 0.01659317]
# [0.71509266 0.26831418 0.01659317]
# [0.71509266 0.26831418 0.01659317]
# [0.71509266 0.26831418 0.01659317]
# [0.71509266 0.26831418 0.01659317]
# [0.71509266 0.26831418 0.01659317]
# [0.71509266 0.26831418 0.01659317]
# [0.71509266 0.26831418 0.01659317]
# [0.71509266 0.26831418 0.01659317]
# [0.71509266 0.26831418 0.01659317]
# [0.71509266 0.26831418 0.01659317]
# [0.71509266 0.26831418 0.01659317]
# [0.71509266 0.26831418 0.01659317]
# [0.71509266 0.26831418 0.01659317]
# [0.71509266 0.26831418 0.01659317]
# [0.71509266 0.26831418 0.01659317]
# [0.71509266 0.26831418 0.01659317]
# [0.71509266 0.26831418 0.01659317]
# [0.7531655  0.2338397  0.01299486]
# [0.7523275  0.23668492 0.01098757]
# [0.737684   0.25193658 0.01037938]
# [0.7292748  0.26089242 0.00983272]
# [0.72326547 0.2675257  0.00920879]
# [0.7179363  0.27344868 0.00861503]
# [0.71207136 0.2798394  0.00808926]
# [0.7037443  0.28858593 0.00766982]
# [0.69038296 0.30220503 0.00741202]
# [0.67094797 0.32167128 0.00738077]
# [0.650021   0.34226763 0.00771134]
# [0.6340157  0.3573142  0.00867014]
# [0.6249597  0.36538863 0.00965164]
# [0.62017095 0.36938602 0.01044301]
# [0.63616383 0.35400248 0.00983377]
0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.9023987  0.09491149 0.00268975]
# [0.90125513 0.09639927 0.00234561]
# [0.89453524 0.10322026 0.00224452]
# [0.8935919  0.1043142  0.00209396]
# [0.89098    0.10708515 0.00193493]
# [0.8807338  0.1176131  0.00165312]
# [0.8669209  0.13172331 0.00135575]
# [0.86038446 0.13847709 0.0011385 ]
# [0.8579515  0.14106198 0.00098657]
# [0.8571873  0.14193788 0.00087483]
# [8.5703063e-01 1.4217950e-01 7.8981783e-04]
# [8.5707289e-01 1.4220273e-01 7.2442909e-04]
# [8.5717160e-01 1.4215454e-01 6.7392190e-04]
# [8.5728049e-01 1.4208461e-01 6.3482759e-04]
# [8.5738921e-01 1.4200631e-01 6.0450699e-04]
# [8.5749298e-01 1.4192605e-01 5.8095093e-04]
# [8.5757995e-01 1.4185740e-01 5.6263054e-04]
# [8.5761845e-01 1.4183319e-01 5.4839934e-04]
# [8.5753590e-01 1.4192675e-01 5.3743657e-04]
# [8.5716498e-01 1.4230588e-01 5.2924990e-04]
# [8.5607684e-01 1.4339930e-01 5.2385923e-04]
# [8.5271710e-01 1.4675969e-01 5.2325195e-04]
# [8.3480042e-01 1.6465040e-01 5.4926006e-04]
# [0.6918309  0.30741024 0.00075883]
# [0.6510325  0.3481808  0.00078672]
# [0.6471133 0.3520376 0.0008491]
# [0.64365214 0.35537246 0.00097549]
# [0.6425651  0.35650986 0.00092507]
# [0.64203125 0.3570579  0.00091089]
# [0.64232254 0.35677144 0.00090598]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]
# [0.6425795  0.3565196  0.00090093]

# %%
cap.release()
out.release()
cv2.destroyAllWindows()

# %%
# for i in Label:
#     print(i)

# %%
Label[0]

# %%
Star("Number 1",31)

# %%
Properties_res[31]

# %%
Mean1N = np.array([265, 415])
cov1N = np.array([[440, 34],[34, 730]])
x, y = np.random.multivariate_normal(Mean1N, cov1N, 1).T
var = multivariate_normal(mean=Mean1N, cov=cov1N)
max_rep = round((var.pdf(np.array([x[0],y[0]]))/var.pdf(Mean1N))**power*multipy)

# %%
x

# %%
Properties_res[i]

# %%
i

# %%
Label[250*30]

# %%
y_pred[250*30]

# %%
Model_data_normal_sequence[250*30,-1]

# %%
if Model_data_normal_sequence[250*30,-1]

# %%
a=y_pred[250*30]
a=a.argmax()
if Model_data_normal_sequence[250*30,-1,6*a]==0:
    y_pred[250*30,a]=0
    a=y_pred[250*30]
    a=a.argmax()

# %%
Model_data_normal_sequence[250*30,-1,6*a]==0

# %%
for j in Persons_inter:
    print(int(j))
    #Look_X, Look_Y = Participants_look(Model_label[j+i],i)
    #cv2.putText(frame, "*", (Look_X, Look_Y), cv2.FONT_HERSHEY_SIMPLEX, 1,(0,0,255),2) #Detecter Model

# %%
import math

radius = 30  # Radius of the circle
num_stars = 11  # Number of stars

for i in range(num_stars):
    angle = i * (2 * math.pi / num_stars)
    x =  radius * math.cos(angle)
    y =  radius * math.sin(angle)
    print(x,y)
# Out:
# 30.0 0.0
# 25.237605984935435 16.219224523667926
# 12.462450390056594 27.28895986063555
# -4.2694451481985505 29.694643256427984
# -19.64582201835855 22.67248723062775
# -28.784789208434923 8.45197670524289
# -28.784789208434923 -8.451976705242881
# -19.645822018358558 -22.672487230627745
# -4.269445148198557 -29.69464325642798
# 12.462450390056581 -27.288959860635558
# 25.237605984935435 -16.219224523667922

# %%
x

# %%
y
